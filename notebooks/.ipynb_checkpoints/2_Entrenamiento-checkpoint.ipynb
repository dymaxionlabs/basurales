# %% [markdown]
# # Basurales: Entrenamiento
#
# El objetivo de este proyecto es la detección de basurales a cielo abierto en la zona del AMBA. Para ello se utiliza un modelo de de machine learning de tipo CNN, dispuesto en una arquitectura denominada U-Net. Este esta especializado en la segmentacion de objetos.
#
# Se exploraron dos 2 tipos de imágenes. Por un lado las imagenes RGB+NIR, provenientes del satélite Sentinel-2, y por otro las imagenes termicas (B10 y B11) del satelite Lansat-8. A su vez, se exploraron diferentes alternativas de información en las imágenes
#
# * Imagen RGB + NIR
# * Imagen RGB + NIR + Imagen termica Lansat 8
#
# Esta información se añade en forma de una  banda extra en la imagen, de este modo pasan a ser de 4 bandas (RGB NIR) a 5 bandas.

# %% [markdown]
# ### Descarga de las imágenes  (vuelo)

# %%
# !gsutil cp -r <PATH>

# %% [markdown]
# ## Preprocesamiento

# %% [markdown]
# ### Imágenes 4D Sentinel 2

# %% [markdown]
# El modelo entrena con un set de imagenes y mascaras binarias que delimitan el objeto de interes.
#
# Este set se generan vía **satproc_extract_chips**. Esta herramienta se utiliza tanto en la generación del dataset de entrenamiento como en el de predicción, en el primer caso se generan las imágenes y las máscaras, y en el segundo solo las imágenes.

# %% [markdown]
# Para generar las imágenes 4D del entrenamiento:

# %%
# !ls ./../data/img/img_train_tmp/2021-01-01_2021-01-30/areas/
# Out:
# fid_0.tif   fid_21.tif	fid_34.tif  fid_47.tif	fid_6.tif   fid_72.tif
# fid_1.tif   fid_22.tif	fid_35.tif  fid_48.tif	fid_60.tif  fid_73.tif
# fid_10.tif  fid_23.tif	fid_36.tif  fid_49.tif	fid_61.tif  fid_74.tif
# fid_11.tif  fid_24.tif	fid_37.tif  fid_5.tif	fid_62.tif  fid_75.tif
# fid_12.tif  fid_25.tif	fid_38.tif  fid_50.tif	fid_63.tif  fid_76.tif
# fid_13.tif  fid_26.tif	fid_39.tif  fid_51.tif	fid_64.tif  fid_77.tif
# fid_14.tif  fid_27.tif	fid_4.tif   fid_52.tif	fid_65.tif  fid_78.tif
# fid_15.tif  fid_28.tif	fid_40.tif  fid_53.tif	fid_66.tif  fid_79.tif
# fid_16.tif  fid_29.tif	fid_41.tif  fid_54.tif	fid_67.tif  fid_8.tif
# fid_17.tif  fid_3.tif	fid_42.tif  fid_55.tif	fid_68.tif  fid_9.tif
# fid_18.tif  fid_30.tif	fid_43.tif  fid_56.tif	fid_69.tif
# fid_19.tif  fid_31.tif	fid_44.tif  fid_57.tif	fid_7.tif
# fid_2.tif   fid_32.tif	fid_45.tif  fid_58.tif	fid_70.tif
# fid_20.tif  fid_33.tif	fid_46.tif  fid_59.tif	fid_71.tif

# %%
# !ls ./../data/shp/gt/basura.shp
# Out:
# LINEA_DE_BASE_BASURALES.cst  basura.prj      basura_cov.shx
# LINEA_DE_BASE_BASURALES.dbf  basura.shp      basurales_4326.gpkg
# LINEA_DE_BASE_BASURALES.prj  basura.shx      basurales_4326.gpkg-shm
# LINEA_DE_BASE_BASURALES.shp  basura_cov.cpg  basurales_4326.gpkg-wal
# LINEA_DE_BASE_BASURALES.shx  basura_cov.dbf  puntos.geojson
# basura.cpg		     basura_cov.prj
# basura.dbf		     basura_cov.shp

# %%
# !satproc_extract_chips \
     ./../data/img/img_train_tmp/2021-01-01_2021-01-30/areas/*.tif \
    -o ./../data/data_train_4D/S2/500_400/ \
    --size 500 \
    --step-size 400 \
    --crs epsg:4326 \
    --aoi ./../data/shp/gt/basura.shp
# Out:
#   0%|                                                    | 0/80 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#  42%|█████████████████▊                        | 34/80 [00:00<00:00, 336.17it/s]
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
#   0%|                                                     | 0/9 [00:00<?, ?it/s]
#  22%|██████████                                   | 2/9 [00:00<00:00, 15.50it/s]
#  44%|████████████████████                         | 4/9 [00:00<00:00, 16.27it/s]
# 100%|█████████████████████████████████████████████| 9/9 [00:00<00:00, 21.86it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#  56%|████████████████████████▏                  | 45/80 [00:00<00:00, 68.73it/s]
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 26.32it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#  84%|████████████████████████████████████       | 67/80 [00:00<00:00, 86.54it/s]
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
#
# 0it [00:00, ?it/s]
# 100%|██████████████████████████████████████████| 80/80 [00:00<00:00, 115.49it/s]

# %% [markdown]
# ###### Donde los argumentos son:
#
# * **El primer argumento** es la ruta a las imágenes
#
# * **o** es la ruta de destino
#
# Recomendamos que dicha ruta sea descriptiva, por ejemplo “data_train/600_600/Remesa08/ ” describe : Data_train → datos usados para entrenar; 400_400 → <tamaño de la imagen >_ <tamaño del step-size> (las imágenes son cuadradas); Remesa08 → Remesa sobre la que vamos a trabajar
#
# * **size** tamaño de las imágenes resultantes (las imágenes son cuadradas)
# * **step-size** paso del proceso. Si *step-size* es igual que el *size* entonces no hay overlap en las imágenes.
#
# En ocaciones es útil para el entrenamiento generar los chips con un overlap de este modo tenemos más datos para entrenar. Pero en la predicción valor debe ser igual al tamaño que la imagen
#
# * **crs** epsg:5382 le asigna un epsg a la imagen
#
# * **label-property** nombre del campo donde se define cada categoría (solo se usa para el entrenamiento)
#
# * **classes** nombres de las clases (como aparecen en el geojson), separados por espacios
#
# * **aoi** ruta al archivo vectorial donde están definidas las localidades. Al definir una region de interés solo se procesan las imágenes que interceptan esas localidades.
#
# Este comando va a generar dos carpetas en la ruta de destino : “images” y “masks”. Los archivos de la primera van a ser de tipo Tiff de 3 bandas (rgb) y los de la segunda van a ser, también, de tipo Tiff pero de N bandas donde N representa el número de clases, en este caso 4. Y donde cada una de las bandas es una máscara binaria

# %%
# !tree data -d
# Out:
# /home/ro/meduy-mda/data
# ├── 4D_S2
# ├── 4D_vuelo
# │   └── parcelas_remesas
# ├── 5D_vuelo
# ├── data_predict
# │   ├── S2
# │   │   ├── 3D
# │   │   │   └── 160_160
# │   │   │       └── images
# │   │   ├── 4D
# │   │   │   └── 160_160
# │   │   │       └── images
# │   │   └── 5D
# │   └── vuelo
# │       ├── 3D
# │       │   └── Remesa09
# │       │       └── images
# │       ├── 4D
# │       │   └── 600_600
# │       │       ├── Remesa01
# │       │       │   └── images
# │       │       ├── Remesa02
# │       │       │   └── images
# │       │       ├── Remesa03
# │       │       │   └── images
# │       │       ├── Remesa04
# │       │       │   └── images
# │       │       ├── Remesa05
# │       │       │   └── images
# │       │       ├── Remesa06
# │       │       │   └── images
# │       │       ├── Remesa07
# │       │       │   └── images
# │       │       ├── Remesa08
# │       │       │   └── images
# │       │       ├── Remesa09
# │       │       │   └── images
# │       │       ├── Remesa10
# │       │       │   └── images
# │       │       ├── Remesa11
# │       │       │   └── images
# │       │       ├── Remesa12
# │       │       │   └── images
# │       │       └── images
# │       └── 5D
# │           └── 600_600
# │               ├── Remesa01
# │               │   └── images
# │               ├── Remesa02
# │               │   └── images
# │               ├── Remesa03
# │               │   └── images
# │               ├── Remesa04
# │               │   └── images
# │               ├── Remesa06
# │               │   └── images
# │               ├── Remesa07
# │               │   └── images
# │               ├── Remesa08
# │               │   └── images
# │               ├── Remesa09
# │               │   └── images
# │               ├── Remesa10
# │               │   └── images
# │               ├── Remesa11
# │               │   └── images
# │               └── Remesa12
# │                   └── images
# ├── data_results
# │   └── S2
# │       ├── 3D
# │       │   └── 160_160
# │       ├── 4D
# │       │   └── 160_160
# │       └── 5D
# ├── data_results_3D_remesa9
# │   └── vuelo
# │       ├── 600-600
# │       │   └── Remesa09
# │       └── 600_600
# │           └── Remesa09
# ├── data_train
# │   ├── S2
# │   │   ├── 3D
# │   │   │   └── 160_60
# │   │   │       ├── images
# │   │   │       └── masks
# │   │   ├── 4D
# │   │   │   └── 160_60
# │   │   │       ├── images
# │   │   │       └── masks
# │   │   └── 5D
# │   │       └── 160_60
# │   │           ├── images
# │   │           └── masks
# │   └── vuelo
# │       ├── 3D
# │       │   └── 600_600
# │       │       ├── images
# │       │       └── masks
# │       ├── 4D
# │       │   └── 600_600
# │       │       ├── images
# │       │       └── masks
# │       └── 5D
# │           └── 600_600
# │               ├── images
# │               └── masks
# ├── ideuy
# ├── sen2
# ├── shp
# ├── tmp
# └── wms
#
# 113 directories

# %% [markdown]
# ### Imágenes 4D

# %% [markdown]
# ![](img/4D.png)

# %% [markdown]
# Como mencionamos anteriormente, tambien es necesario generar los datos de entrenamiento con las imagenes 4D (y 5D) ya que cada modelo es independiente.

# %%
from meduy.postprocess.concatenate import concatenate

input_dir  = 'data/data_train_3D/vuelo/600_600/images/'
output_dir = 'data/data_train_4D/vuelo/600_600/images/'
band_path  = 'data/4D_vuelo/parcelas_remesas/parcelas_remesa_1.tif'  ###

concatenate(input_dir=input_dir,output_dir= output_dir, band_path=band_path)

input_dir  = 'data/data_train_3D/vuelo/600_600/images/'
output_dir = 'data/data_train_4D/vuelo/600_600/images/'
band_path  = 'data/4D_vuelo/parcelas_remesas/parcelas_remesa_6.tif'  ###

concatenate(input_dir=input_dir, output_dir=output_dir,band_path= band_path)

# %% [markdown]
# Además debemos copiar las máscaras.

# %%
# !os.makedirs('data/data_train_4D/vuelo/600_600/masks/', exist_ok=True)
# !cp /home/ro/meduy-mda/data/data_train_3D/vuelo/600_600/masks/* /home/ro/meduy-mda/data/data_train_4D/vuelo/600_600/masks/

# %% [markdown]
# ### Imágenes 5D

# %% [markdown]
# ![](img/5D.png)

# %% [markdown]
# De igual modo generamos las imágenes 5D a partir de las 4D.

# %%
from meduy.postprocess.concatenate import concatenate

input_dir  = 'data/data_train_4D/vuelo/600_600/images/'
output_dir = 'data/data_train_5D/vuelo/600_600/images/'
band_path  = 'data/5D_vuelo/capa_5D.tif'  ###

concatenate(input_dir=input_dir,output_dir= output_dir, band_path=band_path)

# %% [markdown]
# Y copiamos las máscaras.

# %%
#!os.makedirs('data/data_train_5D/vuelo/600_600/masks/', exist_ok=True)
# !cp -r data/data_train_4D/vuelo/600_600/masks data/data_train_5D/vuelo/600_600/

# %%
# !tree data/ -d

# %% [markdown]
# ## Entrenamiento - Vuelo

# %% [markdown]
# ### Entrenamiento 3D

# %% [markdown]
# Las librerías que importamos nos permite acceder a las herramientas que vamos a utilizar a lo largo del proyecto como por ejemplo la función de train y predict  del modelo de Unet.

# %%
from meduy.unet.train import TrainConfig, train
from meduy.unet.evaluate import plot_data_generator
import os
# Out:
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# En esta etapa debemos definir la configuración del modelo de ML

# %%
config_3D = TrainConfig(width=320,  #  tamaño de la imagen procesada por la UNet (debe ser multiplos de 16 , por ej 160, 320,etc)
                     height=320,
                     n_channels=3,  #  número de canales de la imagen, rgb -> 3
                     n_classes=1, # número de clases a clasificar
                     apply_image_augmentation=True, #  si es True , amplia el dataset generando imagenes nuevas a partir de pequeñas variaciones de las ya existentes 
                     seed=42,
                     epochs=15, # Cantidad de veces que el dataset entero puede pasar por el proceso de entrenamiento
                     batch_size=32, #cantidad de datos que se procesan por vez, puede ser limitado por la memoria de gpu disponible (debe ser multiplo de 16)
                     steps_per_epoch=200, #  típicamente debe ser igual al numero de imágenes / el batch_size, si es mayor incrementara el número de imágenes generadas con image augmentation
                     early_stopping_patience=3, # a medida que entrena se guarda los resultados del entrenamiento despues de cada epoch, si el error no varió luego de 3 iteraciones , se corta el proceso porque se entiende que el error ya disminuyó significativamente 
                     validation_split=0.2, # se divide la muestra en training y validation para calcular el error durante el proceso de entrenamiento
                     images_path=os.path.join('./data/data_train','vuelo','3D', '600_600'), #ruta a las imágenes
                     model_path=os.path.join('./weights/', 'UNet_asentamientos_3D_600-600_spe200.h5')) #  ruta al archivo de entrenamiento

# %% [markdown]
# Podemos visualizar alguna de las imágenes y máscaras.

# %%
plot_data_generator(train_config=config_3D, num_samples=3, fig_size=(30,20))

# %% [markdown]
# Ejecuta el entrenamiento.

# %%
res_config_3D = train(config_3D)
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, 320, 320, 3)  0
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 320, 320, 32) 896         input_8[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 320, 320, 32) 9248        conv2d_162[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, 160, 160, 32) 0           conv2d_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 160, 160, 32) 128         max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 160, 160, 64) 18496       batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 160, 160, 64) 36928       conv2d_164[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_37 (MaxPooling2D) (None, 80, 80, 64)   0           conv2d_165[0][0]
# __________________________________________________________________________________________________
# dropout_57 (Dropout)            (None, 80, 80, 64)   0           max_pooling2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 80, 80, 64)   256         dropout_57[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 80, 80, 128)  73856       batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 80, 80, 128)  147584      conv2d_166[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_38 (MaxPooling2D) (None, 40, 40, 128)  0           conv2d_167[0][0]
# __________________________________________________________________________________________________
# dropout_58 (Dropout)            (None, 40, 40, 128)  0           max_pooling2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 40, 40, 128)  512         dropout_58[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 40, 40, 256)  295168      batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 40, 40, 256)  590080      conv2d_168[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_39 (MaxPooling2D) (None, 20, 20, 256)  0           conv2d_169[0][0]
# __________________________________________________________________________________________________
# dropout_59 (Dropout)            (None, 20, 20, 256)  0           max_pooling2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 20, 20, 256)  1024        dropout_59[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 20, 20, 512)  1180160     batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 20, 20, 512)  2359808     conv2d_170[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_40 (MaxPooling2D) (None, 10, 10, 512)  0           conv2d_171[0][0]
# __________________________________________________________________________________________________
# dropout_60 (Dropout)            (None, 10, 10, 512)  0           max_pooling2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 10, 10, 1024) 4719616     dropout_60[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 10, 10, 1024) 9438208     conv2d_172[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_36 (Conv2DTran (None, 20, 20, 512)  2097664     conv2d_173[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 20, 20, 1024) 0           conv2d_transpose_36[0][0]
#                                                                  conv2d_171[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 20, 20, 1024) 4096        concatenate_36[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 20, 20, 512)  4719104     batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 20, 20, 512)  2359808     conv2d_174[0][0]
# __________________________________________________________________________________________________
# dropout_61 (Dropout)            (None, 20, 20, 512)  0           conv2d_175[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_37 (Conv2DTran (None, 40, 40, 256)  524544      dropout_61[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 40, 40, 512)  0           conv2d_transpose_37[0][0]
#                                                                  conv2d_169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 40, 40, 512)  2048        concatenate_37[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 40, 40, 256)  1179904     batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 40, 40, 256)  590080      conv2d_176[0][0]
# __________________________________________________________________________________________________
# dropout_62 (Dropout)            (None, 40, 40, 256)  0           conv2d_177[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_38 (Conv2DTran (None, 80, 80, 128)  131200      dropout_62[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 80, 80, 256)  0           conv2d_transpose_38[0][0]
#                                                                  conv2d_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 80, 80, 256)  1024        concatenate_38[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 80, 80, 128)  295040      batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 80, 80, 128)  147584      conv2d_178[0][0]
# __________________________________________________________________________________________________
# dropout_63 (Dropout)            (None, 80, 80, 128)  0           conv2d_179[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_39 (Conv2DTran (None, 160, 160, 64) 32832       dropout_63[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 160, 160, 128 0           conv2d_transpose_39[0][0]
#                                                                  conv2d_165[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 160, 160, 128 512         concatenate_39[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 160, 160, 64) 73792       batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 160, 160, 64) 36928       conv2d_180[0][0]
# __________________________________________________________________________________________________
# dropout_64 (Dropout)            (None, 160, 160, 64) 0           conv2d_181[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_40 (Conv2DTran (None, 320, 320, 32) 8224        dropout_64[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 320, 320, 64) 0           conv2d_transpose_40[0][0]
#                                                                  conv2d_163[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 320, 320, 32) 18464       concatenate_40[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 320, 320, 32) 9248        conv2d_182[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 320, 320, 1)  33          conv2d_183[0][0]
# ==================================================================================================
# Total params: 31,104,097
# Trainable params: 31,099,297
# Non-trainable params: 4,800
# __________________________________________________________________________________________________
# None
# All images: 1187
# Num. training images: 950
# Num. validation images: 237
# Compile and fit the UNet model
# Epoch 1/15
# 200/200 [==============================] - 160s 801ms/step - loss: 0.2213 - accuracy: 0.7489 - mean_iou: 0.1214 - val_loss: 0.2577 - val_accuracy: 0.7704 - val_mean_iou: 0.0657
#
# Epoch 00001: val_loss improved from inf to 0.25771, saving model to ./weights/UNet_asentamientos_3D_600-600_spe200.h5
# Epoch 2/15
# 200/200 [==============================] - 144s 720ms/step - loss: 0.1665 - accuracy: 0.7394 - mean_iou: 0.2490 - val_loss: 0.3130 - val_accuracy: 0.5711 - val_mean_iou: 0.3507
#
# Epoch 00002: val_loss did not improve from 0.25771
# Epoch 3/15
# 200/200 [==============================] - 141s 705ms/step - loss: 0.1475 - accuracy: 0.7474 - mean_iou: 0.2853 - val_loss: 0.2313 - val_accuracy: 0.6489 - val_mean_iou: 0.4677
#
# Epoch 00003: val_loss improved from 0.25771 to 0.23126, saving model to ./weights/UNet_asentamientos_3D_600-600_spe200.h5
# Epoch 4/15
# 200/200 [==============================] - 141s 704ms/step - loss: 0.1407 - accuracy: 0.7426 - mean_iou: 0.3197 - val_loss: 0.1767 - val_accuracy: 0.7588 - val_mean_iou: 0.1935
#
# Epoch 00004: val_loss improved from 0.23126 to 0.17667, saving model to ./weights/UNet_asentamientos_3D_600-600_spe200.h5
# Epoch 5/15
# 200/200 [==============================] - 145s 723ms/step - loss: 0.1334 - accuracy: 0.7525 - mean_iou: 0.3236 - val_loss: 0.4131 - val_accuracy: 0.7720 - val_mean_iou: 0.1412
#
# Epoch 00005: val_loss did not improve from 0.17667
# Epoch 6/15
# 200/200 [==============================] - 139s 697ms/step - loss: 0.1287 - accuracy: 0.7535 - mean_iou: 0.3431 - val_loss: 0.1363 - val_accuracy: 0.7731 - val_mean_iou: 0.1027
#
# Epoch 00006: val_loss improved from 0.17667 to 0.13627, saving model to ./weights/UNet_asentamientos_3D_600-600_spe200.h5
# Epoch 7/15
# 200/200 [==============================] - 139s 694ms/step - loss: 0.1235 - accuracy: 0.7541 - mean_iou: 0.3622 - val_loss: 0.1146 - val_accuracy: 0.7245 - val_mean_iou: 0.4396
#
# Epoch 00007: val_loss improved from 0.13627 to 0.11463, saving model to ./weights/UNet_asentamientos_3D_600-600_spe200.h5
# Epoch 8/15
# 200/200 [==============================] - 140s 698ms/step - loss: 0.1197 - accuracy: 0.7496 - mean_iou: 0.3839 - val_loss: 0.2435 - val_accuracy: 0.7545 - val_mean_iou: 0.3285
#
# Epoch 00008: val_loss did not improve from 0.11463
# Epoch 9/15
# 200/200 [==============================] - 141s 704ms/step - loss: 0.1176 - accuracy: 0.7571 - mean_iou: 0.3842 - val_loss: 0.2278 - val_accuracy: 0.7603 - val_mean_iou: 0.2655
#
# Epoch 00009: val_loss did not improve from 0.11463
# Epoch 10/15
# 200/200 [==============================] - 142s 710ms/step - loss: 0.1129 - accuracy: 0.7630 - mean_iou: 0.3894 - val_loss: 0.1754 - val_accuracy: 0.6328 - val_mean_iou: 0.4806
#
# Epoch 00010: val_loss did not improve from 0.11463
# Epoch 00010: early stopping

# %% [markdown]
# ### Entrenamiento - 4D

# %%
from meduy.unet.train import TrainConfig, train
from meduy.unet.evaluate import plot_data_generator
import os
# Out:
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
config_4D = TrainConfig(width=320,  #  tamaño de la imagen procesada por la UNet (debe ser multiplos de 16 , por ej 160, 320,etc)
                     height=320,
                     n_channels=4, ### #  número de canales de la imagen, rgb -> 3
                     n_classes=1, # número de clases a clasificar
                     apply_image_augmentation=True, #  si es True , amplia el dataset generando imagenes nuevas a partir de pequeñas variaciones de las ya existentes 
                     seed=42,
                     epochs=15, # Cantidad de veces que el dataset entero puede pasar por el proceso de entrenamiento
                     batch_size=32, #cantidad de datos que se procesan por vez, puede ser limitado por la memoria de gpu disponible (debe ser multiplo de 16)
                     steps_per_epoch=200, #  típicamente debe ser igual al numero de imágenes / el batch_size, si es mayor incrementara el número de imágenes generadas con image augmentation
                     early_stopping_patience=3, # a medida que entrena se guarda los resultados del entrenamiento despues de cada epoch, si el error no varió luego de 3 iteraciones , se corta el proceso porque se entiende que el error ya disminuyó significativamente 
                     validation_split=0.2, # se divide la muestra en training y validation para calcular el error durante el proceso de entrenamiento
                     images_path=os.path.join('./data/data_train/','vuelo','4D', '600_600'),### #ruta a las imágenes
                     model_path=os.path.join('./weights/', 'UNet_asentamientos_4D_600-600_spe200.h5')) #  ruta al archivo de entrenamiento

# %%
res_4D_vuelo = train(config_4D)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 320, 320, 4)  0
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 320, 320, 32) 1184        input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 320, 320, 32) 9248        conv2d_47[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 160, 160, 32) 0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 160, 160, 32) 128         max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 160, 160, 64) 18496       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 160, 160, 64) 36928       conv2d_49[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 80, 80, 64)   0           conv2d_50[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 80, 80, 64)   0           max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 80, 80, 64)   256         dropout_17[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 80, 80, 128)  73856       batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 80, 80, 128)  147584      conv2d_51[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 40, 40, 128)  0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 40, 40, 128)  0           max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 40, 40, 128)  512         dropout_18[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 40, 40, 256)  295168      batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 40, 40, 256)  590080      conv2d_53[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 20, 20, 256)  0           conv2d_54[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 20, 20, 256)  0           max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 20, 20, 256)  1024        dropout_19[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 20, 20, 512)  1180160     batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 20, 20, 512)  2359808     conv2d_55[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 10, 10, 512)  0           conv2d_56[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 10, 10, 512)  0           max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 10, 10, 1024) 4719616     dropout_20[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 10, 10, 1024) 9438208     conv2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 20, 20, 512)  2097664     conv2d_58[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 20, 20, 1024) 0           conv2d_transpose_11[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 20, 20, 1024) 4096        concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 20, 20, 512)  4719104     batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 20, 20, 512)  2359808     conv2d_59[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 20, 20, 512)  0           conv2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 40, 40, 256)  524544      dropout_21[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 40, 40, 512)  0           conv2d_transpose_12[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 40, 40, 512)  2048        concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 40, 40, 256)  1179904     batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 40, 40, 256)  590080      conv2d_61[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 40, 40, 256)  0           conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 80, 80, 128)  131200      dropout_22[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 80, 80, 256)  0           conv2d_transpose_13[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 80, 80, 256)  1024        concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 80, 80, 128)  295040      batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 80, 80, 128)  147584      conv2d_63[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 80, 80, 128)  0           conv2d_64[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 160, 160, 64) 32832       dropout_23[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 160, 160, 128 0           conv2d_transpose_14[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 160, 160, 128 512         concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 160, 160, 64) 73792       batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 160, 160, 64) 36928       conv2d_65[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 160, 160, 64) 0           conv2d_66[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_15 (Conv2DTran (None, 320, 320, 32) 8224        dropout_24[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 320, 320, 64) 0           conv2d_transpose_15[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 320, 320, 32) 18464       concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 320, 320, 32) 9248        conv2d_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 320, 320, 1)  33          conv2d_68[0][0]
# ==================================================================================================
# Total params: 31,104,385
# Trainable params: 31,099,585
# Non-trainable params: 4,800
# __________________________________________________________________________________________________
# None
# All images: 1187
# Num. training images: 950
# Num. validation images: 237
# Compile and fit the UNet model
# Epoch 1/15
# 200/200 [==============================] - 829s 4s/step - loss: 0.2884 - accuracy: 0.7446 - mean_iou: 0.0979 - val_loss: 0.2190 - val_accuracy: 0.7198 - val_mean_iou: 0.2338
#
# Epoch 00001: val_loss improved from inf to 0.21903, saving model to ./weights/UNet_asentamientos_4D_600-600_spe200.h5
# Epoch 2/15
# 200/200 [==============================] - 755s 4s/step - loss: 0.1722 - accuracy: 0.7421 - mean_iou: 0.2040 - val_loss: 0.4017 - val_accuracy: 0.5737 - val_mean_iou: 0.3576
#
# Epoch 00002: val_loss did not improve from 0.21903
# Epoch 3/15
# 200/200 [==============================] - 764s 4s/step - loss: 0.1584 - accuracy: 0.7379 - mean_iou: 0.2780 - val_loss: 0.2097 - val_accuracy: 0.7539 - val_mean_iou: 0.1207
#
# Epoch 00003: val_loss improved from 0.21903 to 0.20973, saving model to ./weights/UNet_asentamientos_4D_600-600_spe200.h5
# Epoch 4/15
# 200/200 [==============================] - 776s 4s/step - loss: 0.1490 - accuracy: 0.7409 - mean_iou: 0.3056 - val_loss: 0.1939 - val_accuracy: 0.6688 - val_mean_iou: 0.3401
#
# Epoch 00004: val_loss improved from 0.20973 to 0.19392, saving model to ./weights/UNet_asentamientos_4D_600-600_spe200.h5
# Epoch 5/15
# 200/200 [==============================] - 769s 4s/step - loss: 0.1416 - accuracy: 0.7354 - mean_iou: 0.3399 - val_loss: 0.1918 - val_accuracy: 0.6624 - val_mean_iou: 0.3971
#
# Epoch 00005: val_loss improved from 0.19392 to 0.19182, saving model to ./weights/UNet_asentamientos_4D_600-600_spe200.h5
# Epoch 6/15
# 200/200 [==============================] - 767s 4s/step - loss: 0.1354 - accuracy: 0.7469 - mean_iou: 0.3438 - val_loss: 0.1659 - val_accuracy: 0.7800 - val_mean_iou: 0.2340
#
# Epoch 00006: val_loss improved from 0.19182 to 0.16586, saving model to ./weights/UNet_asentamientos_4D_600-600_spe200.h5
# Epoch 7/15
# 200/200 [==============================] - 775s 4s/step - loss: 0.1274 - accuracy: 0.7518 - mean_iou: 0.3604 - val_loss: 0.2303 - val_accuracy: 0.7791 - val_mean_iou: 0.1628
#
# Epoch 00007: val_loss did not improve from 0.16586
# Epoch 8/15
# 200/200 [==============================] - 771s 4s/step - loss: 0.1237 - accuracy: 0.7457 - mean_iou: 0.3896 - val_loss: 0.1094 - val_accuracy: 0.7789 - val_mean_iou: 0.3198
#
# Epoch 00008: val_loss improved from 0.16586 to 0.10937, saving model to ./weights/UNet_asentamientos_4D_600-600_spe200.h5
# Epoch 9/15
# 200/200 [==============================] - 771s 4s/step - loss: 0.1197 - accuracy: 0.7537 - mean_iou: 0.3902 - val_loss: 0.1743 - val_accuracy: 0.7931 - val_mean_iou: 0.2564
#
# Epoch 00009: val_loss did not improve from 0.10937
# Epoch 10/15
# 200/200 [==============================] - 774s 4s/step - loss: 0.1176 - accuracy: 0.7429 - mean_iou: 0.4194 - val_loss: 0.0901 - val_accuracy: 0.7648 - val_mean_iou: 0.3638
#
# Epoch 00010: val_loss improved from 0.10937 to 0.09006, saving model to ./weights/UNet_asentamientos_4D_600-600_spe200.h5
# Epoch 11/15
# 200/200 [==============================] - 776s 4s/step - loss: 0.1099 - accuracy: 0.7538 - mean_iou: 0.4296 - val_loss: 0.1329 - val_accuracy: 0.7490 - val_mean_iou: 0.3997
#
# Epoch 00011: val_loss did not improve from 0.09006
# Epoch 12/15
# 200/200 [==============================] - 780s 4s/step - loss: 0.1068 - accuracy: 0.7533 - mean_iou: 0.4414 - val_loss: 0.1834 - val_accuracy: 0.6887 - val_mean_iou: 0.4632
#
# Epoch 00012: val_loss did not improve from 0.09006
# Epoch 13/15
# 200/200 [==============================] - 799s 4s/step - loss: 0.0997 - accuracy: 0.7518 - mean_iou: 0.4615 - val_loss: 0.0997 - val_accuracy: 0.6993 - val_mean_iou: 0.4419
#
# Epoch 00013: val_loss did not improve from 0.09006
# Epoch 00013: early stopping
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/keras/utils/data_utils.py in get(self)
#     710                     future = self.queue.get(block=True)
# --> 711                     inputs = future.get(timeout=30)
#     712                     self.queue.task_done()
#
# ~/miniconda3/envs/tf-gpu/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     656         else:
# --> 657             raise self._value
#     658
#
# ~/miniconda3/envs/tf-gpu/lib/python3.7/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     120         try:
# --> 121             result = (True, func(*args, **kwds))
#     122         except Exception as e:
#
# ~/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/keras/utils/data_utils.py in next_sample(uid)
#     649     """
# --> 650     return six.next(_SHARED_SEQUENCES[uid])
#     651
#
# ValueError: generator already executing
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-844bc92964e2> in <module>
# ----> 1 res_4D_vuelo = train(config_4D)
#
# ~/meduy-ml/src/meduy/unet/train.py in train(cfg)
#     336
#     337     scores = model.evaluate_generator(val_generator,
# --> 338                                       steps=len(val_images) // cfg.batch_size)
#     339     loss, accuracy, mean_iou = scores
#     340     print("*** Final validation metrics ***")
#
# ~/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/keras/engine/training.py in evaluate_generator(self, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#    1789             workers=workers,
#    1790             use_multiprocessing=use_multiprocessing,
# -> 1791             verbose=verbose)
#    1792
#    1793     @interfaces.legacy_generator_methods_support
#
# ~/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/keras/engine/training_generator.py in evaluate_generator(model, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#     363
#     364         while steps_done < steps:
# --> 365             generator_output = next(output_generator)
#     366             if not hasattr(generator_output, '__len__'):
#     367                 raise ValueError('Output of generator should be a tuple '
#
# ~/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/keras/utils/data_utils.py in get(self)
#     736             if 'generator already executing' in str(e):
#     737                 raise RuntimeError(
# --> 738                     "Your generator is NOT thread-safe."
#     739                     "Keras requires a thread-safe generator when"
#     740                     "`use_multiprocessing=False, workers > 1`."
#
# RuntimeError: Your generator is NOT thread-safe.Keras requires a thread-safe generator when`use_multiprocessing=False, workers > 1`.For more information see issue #1638.

# %%
 import matplotlib.pyplot as plt

plt.figure(figsize=(16,4))

plt.subplot(121)
plt.plot(res_4D_vuelo.history['loss'])
plt.plot(res_4D_vuelo.history['val_loss'])
plt.title('Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')

plt.subplot(122)
plt.plot(res_4D_vuelo.history['mean_iou'])
plt.plot(res_4D_vuelo.history['val_mean_iou'])
plt.title('Mean IoU')
plt.ylabel('Mean IoU')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')

plt.show()

# %% [markdown]
# ### Entrenamiento -  5D

# %%
from meduy.unet.train import TrainConfig, train
from meduy.unet.evaluate import plot_data_generator
import os
# Out:
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
config_5D = TrainConfig(width=320,  #  tamaño de la imagen procesada por la UNet (debe ser multiplos de 16 , por ej 160, 320,etc)
                     height=320,
                     n_channels=5, ### #  número de canales de la imagen, rgb -> 3
                     n_classes=1, # número de clases a clasificar
                     apply_image_augmentation=True, #  si es True , amplia el dataset generando imagenes nuevas a partir de pequeñas variaciones de las ya existentes 
                     seed=42,
                     epochs=15, # Cantidad de veces que el dataset entero puede pasar por el proceso de entrenamiento
                     batch_size=32, #cantidad de datos que se procesan por vez, puede ser limitado por la memoria de gpu disponible (debe ser multiplo de 16)
                     steps_per_epoch=200, #  típicamente debe ser igual al numero de imágenes / el batch_size, si es mayor incrementara el número de imágenes generadas con image augmentation
                     early_stopping_patience=3, # a medida que entrena se guarda los resultados del entrenamiento despues de cada epoch, si el error no varió luego de 3 iteraciones , se corta el proceso porque se entiende que el error ya disminuyó significativamente 
                     validation_split=0.2, # se divide la muestra en training y validation para calcular el error durante el proceso de entrenamiento

                     images_path=os.path.join('./data/data_train/','vuelo','5D', '600_600'),### #ruta a las imágenes
                     model_path=os.path.join('./weights/', 'UNet_asentamientos_5D_600-600_spe200.h5')) #  ruta al archivo de entrenamiento

# %%
res_5D_vuelo = train(config_5D)
# Out:
# WARNING:tensorflow:From /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 320, 320, 5)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 320, 320, 32) 1472        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 320, 320, 32) 9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 160, 160, 32) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 160, 160, 32) 128         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 160, 160, 64) 18496       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 160, 160, 64) 36928       conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 80, 80, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 80, 80, 64)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 80, 80, 64)   256         dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 80, 80, 128)  73856       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 80, 80, 128)  147584      conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 40, 40, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 40, 40, 128)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 40, 40, 128)  512         dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 40, 40, 256)  295168      batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 40, 40, 256)  590080      conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 20, 20, 256)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 20, 20, 256)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 20, 20, 256)  1024        dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 20, 20, 512)  1180160     batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 20, 20, 512)  2359808     conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 10, 10, 512)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 10, 10, 512)  0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 10, 10, 1024) 4719616     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 10, 10, 1024) 9438208     conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 20, 20, 512)  2097664     conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 20, 20, 1024) 0           conv2d_transpose_1[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 20, 20, 1024) 4096        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 20, 20, 512)  4719104     batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 20, 20, 512)  2359808     conv2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 20, 20, 512)  0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 40, 40, 256)  524544      dropout_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 40, 40, 512)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 40, 40, 512)  2048        concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 40, 40, 256)  1179904     batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 40, 40, 256)  590080      conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 40, 40, 256)  0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 80, 80, 128)  131200      dropout_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 80, 80, 256)  0           conv2d_transpose_3[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 80, 80, 256)  1024        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 80, 80, 128)  295040      batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 80, 80, 128)  147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 80, 80, 128)  0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 160, 160, 64) 32832       dropout_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 160, 160, 128 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 160, 160, 128 512         concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 160, 160, 64) 73792       batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 160, 160, 64) 36928       conv2d_19[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 160, 160, 64) 0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 320, 320, 32) 8224        dropout_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 320, 320, 64) 0           conv2d_transpose_5[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 320, 320, 32) 18464       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 320, 320, 32) 9248        conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 320, 320, 1)  33          conv2d_22[0][0]
# ==================================================================================================
# Total params: 31,104,673
# Trainable params: 31,099,873
# Non-trainable params: 4,800
# __________________________________________________________________________________________________
# None
# All images: 1187
# Num. training images: 950
# Num. validation images: 237
# Compile and fit the UNet model
# WARNING:tensorflow:From /home/ro/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/15
# 200/200 [==============================] - 1008s 5s/step - loss: 0.2920 - accuracy: 0.7147 - mean_iou: 0.1645 - val_loss: 0.2472 - val_accuracy: 0.7473 - val_mean_iou: 0.2300
#
# Epoch 00001: val_loss improved from inf to 0.24724, saving model to ./weights/UNet_asentamientos_5D_600-600_spe200.h5
# Epoch 2/15
# 200/200 [==============================] - 947s 5s/step - loss: 0.1646 - accuracy: 0.7386 - mean_iou: 0.2601 - val_loss: 0.4192 - val_accuracy: 0.8032 - val_mean_iou: 0.0045
#
# Epoch 00002: val_loss did not improve from 0.24724
# Epoch 3/15
# 200/200 [==============================] - 948s 5s/step - loss: 0.1483 - accuracy: 0.7406 - mean_iou: 0.3001 - val_loss: 0.2296 - val_accuracy: 0.7824 - val_mean_iou: 0.1361
#
# Epoch 00003: val_loss improved from 0.24724 to 0.22962, saving model to ./weights/UNet_asentamientos_5D_600-600_spe200.h5
# Epoch 4/15
# 200/200 [==============================] - 946s 5s/step - loss: 0.1400 - accuracy: 0.7489 - mean_iou: 0.3134 - val_loss: 0.1386 - val_accuracy: 0.7418 - val_mean_iou: 0.3406
#
# Epoch 00004: val_loss improved from 0.22962 to 0.13860, saving model to ./weights/UNet_asentamientos_5D_600-600_spe200.h5
# Epoch 5/15
# 200/200 [==============================] - 951s 5s/step - loss: 0.1362 - accuracy: 0.7427 - mean_iou: 0.3407 - val_loss: 0.1297 - val_accuracy: 0.7825 - val_mean_iou: 0.2948
#
# Epoch 00005: val_loss improved from 0.13860 to 0.12968, saving model to ./weights/UNet_asentamientos_5D_600-600_spe200.h5
# Epoch 6/15
# 200/200 [==============================] - 965s 5s/step - loss: 0.1276 - accuracy: 0.7395 - mean_iou: 0.3703 - val_loss: 0.1539 - val_accuracy: 0.7400 - val_mean_iou: 0.3883
#
# Epoch 00006: val_loss did not improve from 0.12968
# Epoch 7/15
# 200/200 [==============================] - 981s 5s/step - loss: 0.1244 - accuracy: 0.7430 - mean_iou: 0.3762 - val_loss: 0.2282 - val_accuracy: 0.8065 - val_mean_iou: 0.0277
#
# Epoch 00007: val_loss did not improve from 0.12968
# Epoch 8/15
# 200/200 [==============================] - 984s 5s/step - loss: 0.1222 - accuracy: 0.7492 - mean_iou: 0.3702 - val_loss: 0.1340 - val_accuracy: 0.7368 - val_mean_iou: 0.3990
#
# Epoch 00008: val_loss did not improve from 0.12968
# Epoch 00008: early stopping

# %% [markdown]
# ## Preprocesamiento: Sentinel 2

# %% [markdown]
# ### Imágenes 3D

# %% [markdown]
# ![](img/s2.png)

# %% [markdown]
# Generamos las imágenes y máscaras para el entrenamiento.

# %%
# !meduy_extract_chips data/tmp/S2/*.tif \
                     -o data/data_train_3D/S2/160_60/ \
                     --size 160 \
                     --step-size 60 \
                     --crs epsg:5382 \
                     --aoi data/shp/asentamientos_mvd_2018.geojson

# %% [markdown]
# ### Imágenes 4D

# %% [markdown]
# ![](img/s2_4D.png)

# %%
from meduy.postprocess import concatenate

input_dir  = 'data/data_train_3D_S2/160_60/images/*.tif'
output_dir = 'data_train_4D_S2/160_60/images/'
band_path  = 'data/4D_S2/capa_4D_.tif'

concatenate(input_dir, output_dir, band_path)

input_dir  = 'data/data_train_3D_S2/160_60/images/*.tif'
output_dir = 'data/data_train_4D_S2/160_60/images/'
band_path  = 'data/4D_S2/capa_4D_.tif'

concatenate(input_dir, output_dir, band_path)

# %%
# !os.makedirs('data/data_train_4D_S2/160_60/masks/', exist_ok=True)
# !cp data/data_train_4D_S2/160_60/masks/* data/data_train_5D/vuelo/600_600/masks/

# %% [markdown]
# ### Imágenes 5D

# %% [markdown]
# ![](img/s25d.png)

# %%
from meduy.postprocess import concatenate

input_dir  = 'data/data_train_4D/vuelo/600_600/images/*.tif'
output_dir = 'data/data_train_5D/vuelo/600_600/images/'
band_path  = 'data/5D_vuelo/capa_5D.tif'

concatenate(input_dir, output_dir, band_path)

# %%
# !os.makedirs('data/data_train_5D/vuelo/600_600/masks/', exist_ok=True)
# !cp data/data_train_4D/vuelo/600_600/masks/* data/data_train_5D/vuelo/600_600/masks/

# %% [markdown]
# ## Entrenamiento - Sentinel 2

# %% [markdown]
# ### Imágenes 3D

# %%
from meduy.unet.train import TrainConfig, train
from meduy.unet.evaluate import plot_data_generator
import os

# %%
config_3D_S2 = TrainConfig(width=160,  #  tamaño de la imagen procesada por la UNet (debe ser multiplos de 16 , por ej 160, 320,etc)
                     height=160,
                     n_channels=3, ### #  número de canales de la imagen, rgb -> 3
                     n_classes=1, # número de clases a clasificar
                     apply_image_augmentation=True, #  si es True , amplia el dataset generando imagenes nuevas a partir de pequeñas variaciones de las ya existentes 
                     seed=42,
                     epochs=15, # Cantidad de veces que el dataset entero puede pasar por el proceso de entrenamiento
                     batch_size=32, #cantidad de datos que se procesan por vez, puede ser limitado por la memoria de gpu disponible (debe ser multiplo de 16)
                     steps_per_epoch=500, #  típicamente debe ser igual al numero de imágenes / el batch_size, si es mayor incrementara el número de imágenes generadas con image augmentation
                     early_stopping_patience=3, # a medida que entrena se guarda los resultados del entrenamiento despues de cada epoch, si el error no varió luego de 3 iteraciones , se corta el proceso porque se entiende que el error ya disminuyó significativamente 
                     validation_split=0.2, # se divide la muestra en training y validation para calcular el error durante el proceso de entrenamiento
                     images_path=os.path.join('./data/data_train','S2','3D', '160_60'),### #ruta a las imágenes
                     model_path=os.path.join('./weights/', 'UNet_asentamientos_S2_3D_160_60_spe500.h5')) #  ruta al archivo de entrenamiento

# %%
res_config_3D_S2 = train(config_3D_S2)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 160, 160, 3)  0
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 160, 160, 32) 896         input_5[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 160, 160, 32) 9248        conv2d_93[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 80, 80, 32)   0           conv2d_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 80, 80, 32)   128         max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 80, 80, 64)   18496       batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 80, 80, 64)   36928       conv2d_95[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 40, 40, 64)   0           conv2d_96[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 40, 40, 64)   0           max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 40, 40, 64)   256         dropout_33[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 40, 40, 128)  73856       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 40, 40, 128)  147584      conv2d_97[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 20, 20, 128)  0           conv2d_98[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 20, 20, 128)  0           max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 20, 20, 128)  512         dropout_34[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 20, 20, 256)  295168      batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 20, 20, 256)  590080      conv2d_99[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 10, 10, 256)  0           conv2d_100[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 10, 10, 256)  0           max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 10, 10, 256)  1024        dropout_35[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 10, 10, 512)  1180160     batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 10, 10, 512)  2359808     conv2d_101[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 5, 5, 512)    0           conv2d_102[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 5, 5, 512)    0           max_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 5, 5, 1024)   4719616     dropout_36[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 5, 5, 1024)   9438208     conv2d_103[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_21 (Conv2DTran (None, 10, 10, 512)  2097664     conv2d_104[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 10, 10, 1024) 0           conv2d_transpose_21[0][0]
#                                                                  conv2d_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 10, 10, 1024) 4096        concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 10, 10, 512)  4719104     batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 10, 10, 512)  2359808     conv2d_105[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 10, 10, 512)  0           conv2d_106[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_22 (Conv2DTran (None, 20, 20, 256)  524544      dropout_37[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 20, 20, 512)  0           conv2d_transpose_22[0][0]
#                                                                  conv2d_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 20, 20, 512)  2048        concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 20, 20, 256)  1179904     batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 20, 20, 256)  590080      conv2d_107[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 20, 20, 256)  0           conv2d_108[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 40, 40, 128)  131200      dropout_38[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 40, 40, 256)  0           conv2d_transpose_23[0][0]
#                                                                  conv2d_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 40, 40, 256)  1024        concatenate_23[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 40, 40, 128)  295040      batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 40, 40, 128)  147584      conv2d_109[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 40, 40, 128)  0           conv2d_110[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_24 (Conv2DTran (None, 80, 80, 64)   32832       dropout_39[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 80, 80, 128)  0           conv2d_transpose_24[0][0]
#                                                                  conv2d_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 80, 80, 128)  512         concatenate_24[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 80, 80, 64)   73792       batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 80, 80, 64)   36928       conv2d_111[0][0]
# __________________________________________________________________________________________________
# dropout_40 (Dropout)            (None, 80, 80, 64)   0           conv2d_112[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_25 (Conv2DTran (None, 160, 160, 32) 8224        dropout_40[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 160, 160, 64) 0           conv2d_transpose_25[0][0]
#                                                                  conv2d_94[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 160, 160, 32) 18464       concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 160, 160, 32) 9248        conv2d_113[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 160, 160, 1)  33          conv2d_114[0][0]
# ==================================================================================================
# Total params: 31,104,097
# Trainable params: 31,099,297
# Non-trainable params: 4,800
# __________________________________________________________________________________________________
# None
# All images: 847
# Num. training images: 678
# Num. validation images: 169
# Compile and fit the UNet model
# Epoch 1/15
# 500/500 [==============================] - 124s 249ms/step - loss: 0.0591 - accuracy: 0.9660 - mean_iou: 0.0552 - val_loss: 0.0870 - val_accuracy: 0.9107 - val_mean_iou: 0.1624
#
# Epoch 00001: val_loss improved from inf to 0.08696, saving model to ./weights/UNet_asentamientos_S2_3D_160_60_spe500.h5
# Epoch 2/15
# 500/500 [==============================] - 119s 238ms/step - loss: 0.0340 - accuracy: 0.9749 - mean_iou: 0.1773 - val_loss: 0.0309 - val_accuracy: 0.9734 - val_mean_iou: 0.1366
#
# Epoch 00002: val_loss improved from 0.08696 to 0.03090, saving model to ./weights/UNet_asentamientos_S2_3D_160_60_spe500.h5
# Epoch 3/15
# 500/500 [==============================] - 120s 240ms/step - loss: 0.0282 - accuracy: 0.9786 - mean_iou: 0.2605 - val_loss: 0.0507 - val_accuracy: 0.9691 - val_mean_iou: 0.3024
#
# Epoch 00003: val_loss did not improve from 0.03090
# Epoch 4/15
# 500/500 [==============================] - 120s 241ms/step - loss: 0.0239 - accuracy: 0.9814 - mean_iou: 0.3343 - val_loss: 0.0504 - val_accuracy: 0.9655 - val_mean_iou: 0.2749
#
# Epoch 00004: val_loss did not improve from 0.03090
# Epoch 5/15
# 500/500 [==============================] - 120s 240ms/step - loss: 0.0209 - accuracy: 0.9834 - mean_iou: 0.3985 - val_loss: 0.0187 - val_accuracy: 0.9821 - val_mean_iou: 0.4267
#
# Epoch 00005: val_loss improved from 0.03090 to 0.01871, saving model to ./weights/UNet_asentamientos_S2_3D_160_60_spe500.h5
# Epoch 6/15
# 500/500 [==============================] - 120s 239ms/step - loss: 0.0187 - accuracy: 0.9849 - mean_iou: 0.4430 - val_loss: 0.0184 - val_accuracy: 0.9846 - val_mean_iou: 0.4459
#
# Epoch 00006: val_loss improved from 0.01871 to 0.01836, saving model to ./weights/UNet_asentamientos_S2_3D_160_60_spe500.h5
# Epoch 7/15
# 500/500 [==============================] - 120s 239ms/step - loss: 0.0170 - accuracy: 0.9861 - mean_iou: 0.4849 - val_loss: 0.0236 - val_accuracy: 0.9837 - val_mean_iou: 0.4060
#
# Epoch 00007: val_loss did not improve from 0.01836
# Epoch 8/15
# 500/500 [==============================] - 119s 239ms/step - loss: 0.0152 - accuracy: 0.9875 - mean_iou: 0.5254 - val_loss: 0.0105 - val_accuracy: 0.9867 - val_mean_iou: 0.5332
#
# Epoch 00008: val_loss improved from 0.01836 to 0.01049, saving model to ./weights/UNet_asentamientos_S2_3D_160_60_spe500.h5
# Epoch 9/15
# 500/500 [==============================] - 119s 239ms/step - loss: 0.0147 - accuracy: 0.9877 - mean_iou: 0.5477 - val_loss: 0.0193 - val_accuracy: 0.9855 - val_mean_iou: 0.5092
#
# Epoch 00009: val_loss did not improve from 0.01049
# Epoch 10/15
# 500/500 [==============================] - 120s 239ms/step - loss: 0.0138 - accuracy: 0.9885 - mean_iou: 0.5675 - val_loss: 0.0137 - val_accuracy: 0.9877 - val_mean_iou: 0.5659
#
# Epoch 00010: val_loss did not improve from 0.01049
# Epoch 11/15
# 500/500 [==============================] - 120s 239ms/step - loss: 0.0134 - accuracy: 0.9887 - mean_iou: 0.5813 - val_loss: 0.0477 - val_accuracy: 0.9764 - val_mean_iou: 0.1910
#
# Epoch 00011: val_loss did not improve from 0.01049
# Epoch 00011: early stopping

# %% [markdown]
# ### Imágenes 4D

# %%
from meduy.unet.train import TrainConfig, train
from meduy.unet.evaluate import plot_data_generator
import os

# %%
config_4D_S2 = TrainConfig(width=160,  #  tamaño de la imagen procesada por la UNet (debe ser multiplos de 16 , por ej 160, 320,etc)
                     height=160,
                     n_channels=4, ### #  número de canales de la imagen, rgb -> 3
                     n_classes=1, # número de clases a clasificar
                     apply_image_augmentation=True, #  si es True , amplia el dataset generando imagenes nuevas a partir de pequeñas variaciones de las ya existentes 
                     seed=42,
                     epochs=15, # Cantidad de veces que el dataset entero puede pasar por el proceso de entrenamiento
                     batch_size=32, #cantidad de datos que se procesan por vez, puede ser limitado por la memoria de gpu disponible (debe ser multiplo de 16)
                     steps_per_epoch=500, #  típicamente debe ser igual al numero de imágenes / el batch_size, si es mayor incrementara el número de imágenes generadas con image augmentation
                     early_stopping_patience=3, # a medida que entrena se guarda los resultados del entrenamiento despues de cada epoch, si el error no varió luego de 3 iteraciones , se corta el proceso porque se entiende que el error ya disminuyó significativamente 
                     validation_split=0.2, # se divide la muestra en training y validation para calcular el error durante el proceso de entrenamiento
                     images_path=os.path.join('./data/data_train/','S2','4D', '160_60'),### #ruta a las imágenes
                     model_path=os.path.join('./weights/', 'UNet_asentamientos_S2_4D_160_60_spe500.h5')) #  ruta al archivo de entrenamiento

# %%
res_config_4D_S2 = train(config_4D_S2)
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 160, 160, 4)  0
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 160, 160, 32) 1184        input_6[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 160, 160, 32) 9248        conv2d_116[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 80, 80, 32)   0           conv2d_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 80, 80, 32)   128         max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 80, 80, 64)   18496       batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 80, 80, 64)   36928       conv2d_118[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 40, 40, 64)   0           conv2d_119[0][0]
# __________________________________________________________________________________________________
# dropout_41 (Dropout)            (None, 40, 40, 64)   0           max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 40, 40, 64)   256         dropout_41[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 40, 40, 128)  73856       batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 40, 40, 128)  147584      conv2d_120[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D) (None, 20, 20, 128)  0           conv2d_121[0][0]
# __________________________________________________________________________________________________
# dropout_42 (Dropout)            (None, 20, 20, 128)  0           max_pooling2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 20, 20, 128)  512         dropout_42[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 20, 20, 256)  295168      batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 20, 20, 256)  590080      conv2d_122[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 10, 10, 256)  0           conv2d_123[0][0]
# __________________________________________________________________________________________________
# dropout_43 (Dropout)            (None, 10, 10, 256)  0           max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 10, 10, 256)  1024        dropout_43[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 10, 10, 512)  1180160     batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 10, 10, 512)  2359808     conv2d_124[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D) (None, 5, 5, 512)    0           conv2d_125[0][0]
# __________________________________________________________________________________________________
# dropout_44 (Dropout)            (None, 5, 5, 512)    0           max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 5, 5, 1024)   4719616     dropout_44[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 5, 5, 1024)   9438208     conv2d_126[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_26 (Conv2DTran (None, 10, 10, 512)  2097664     conv2d_127[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 10, 10, 1024) 0           conv2d_transpose_26[0][0]
#                                                                  conv2d_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 10, 10, 1024) 4096        concatenate_26[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 10, 10, 512)  4719104     batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 10, 10, 512)  2359808     conv2d_128[0][0]
# __________________________________________________________________________________________________
# dropout_45 (Dropout)            (None, 10, 10, 512)  0           conv2d_129[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_27 (Conv2DTran (None, 20, 20, 256)  524544      dropout_45[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 20, 20, 512)  0           conv2d_transpose_27[0][0]
#                                                                  conv2d_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 20, 20, 512)  2048        concatenate_27[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 20, 20, 256)  1179904     batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 20, 20, 256)  590080      conv2d_130[0][0]
# __________________________________________________________________________________________________
# dropout_46 (Dropout)            (None, 20, 20, 256)  0           conv2d_131[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_28 (Conv2DTran (None, 40, 40, 128)  131200      dropout_46[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 40, 40, 256)  0           conv2d_transpose_28[0][0]
#                                                                  conv2d_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 40, 40, 256)  1024        concatenate_28[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 40, 40, 128)  295040      batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 40, 40, 128)  147584      conv2d_132[0][0]
# __________________________________________________________________________________________________
# dropout_47 (Dropout)            (None, 40, 40, 128)  0           conv2d_133[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_29 (Conv2DTran (None, 80, 80, 64)   32832       dropout_47[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 80, 80, 128)  0           conv2d_transpose_29[0][0]
#                                                                  conv2d_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 80, 80, 128)  512         concatenate_29[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 80, 80, 64)   73792       batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 80, 80, 64)   36928       conv2d_134[0][0]
# __________________________________________________________________________________________________
# dropout_48 (Dropout)            (None, 80, 80, 64)   0           conv2d_135[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_30 (Conv2DTran (None, 160, 160, 32) 8224        dropout_48[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 160, 160, 64) 0           conv2d_transpose_30[0][0]
#                                                                  conv2d_117[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 160, 160, 32) 18464       concatenate_30[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 160, 160, 32) 9248        conv2d_136[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 160, 160, 1)  33          conv2d_137[0][0]
# ==================================================================================================
# Total params: 31,104,385
# Trainable params: 31,099,585
# Non-trainable params: 4,800
# __________________________________________________________________________________________________
# None
# All images: 847
# Num. training images: 678
# Num. validation images: 169
# Compile and fit the UNet model
# Epoch 1/15
# 500/500 [==============================] - 407s 814ms/step - loss: 0.0541 - accuracy: 0.9694 - mean_iou: 0.0907 - val_loss: 0.0436 - val_accuracy: 0.9671 - val_mean_iou: 0.1961
#
# Epoch 00001: val_loss improved from inf to 0.04360, saving model to ./weights/UNet_asentamientos_S2_4D_160_60_spe500.h5
# Epoch 2/15
# 500/500 [==============================] - 395s 789ms/step - loss: 0.0299 - accuracy: 0.9782 - mean_iou: 0.2119 - val_loss: 0.0370 - val_accuracy: 0.9757 - val_mean_iou: 0.2265
#
# Epoch 00002: val_loss improved from 0.04360 to 0.03700, saving model to ./weights/UNet_asentamientos_S2_4D_160_60_spe500.h5
# Epoch 3/15
# 500/500 [==============================] - 400s 799ms/step - loss: 0.0241 - accuracy: 0.9816 - mean_iou: 0.3029 - val_loss: 0.0233 - val_accuracy: 0.9788 - val_mean_iou: 0.3595
#
# Epoch 00003: val_loss improved from 0.03700 to 0.02331, saving model to ./weights/UNet_asentamientos_S2_4D_160_60_spe500.h5
# Epoch 4/15
# 500/500 [==============================] - 400s 800ms/step - loss: 0.0208 - accuracy: 0.9836 - mean_iou: 0.3786 - val_loss: 0.0299 - val_accuracy: 0.9818 - val_mean_iou: 0.4032
#
# Epoch 00004: val_loss did not improve from 0.02331
# Epoch 5/15
# 500/500 [==============================] - 398s 795ms/step - loss: 0.0181 - accuracy: 0.9854 - mean_iou: 0.4313 - val_loss: 0.0264 - val_accuracy: 0.9845 - val_mean_iou: 0.4639
#
# Epoch 00005: val_loss did not improve from 0.02331
# Epoch 6/15
# 500/500 [==============================] - 400s 801ms/step - loss: 0.0165 - accuracy: 0.9865 - mean_iou: 0.4762 - val_loss: 0.0159 - val_accuracy: 0.9849 - val_mean_iou: 0.4957
#
# Epoch 00006: val_loss improved from 0.02331 to 0.01595, saving model to ./weights/UNet_asentamientos_S2_4D_160_60_spe500.h5
# Epoch 7/15
# 500/500 [==============================] - 400s 800ms/step - loss: 0.0148 - accuracy: 0.9877 - mean_iou: 0.5166 - val_loss: 0.0122 - val_accuracy: 0.9855 - val_mean_iou: 0.4797
#
# Epoch 00007: val_loss improved from 0.01595 to 0.01222, saving model to ./weights/UNet_asentamientos_S2_4D_160_60_spe500.h5
# Epoch 8/15
# 500/500 [==============================] - 401s 801ms/step - loss: 0.0139 - accuracy: 0.9885 - mean_iou: 0.5364 - val_loss: 0.0097 - val_accuracy: 0.9858 - val_mean_iou: 0.4949
#
# Epoch 00008: val_loss improved from 0.01222 to 0.00970, saving model to ./weights/UNet_asentamientos_S2_4D_160_60_spe500.h5
# Epoch 9/15
# 500/500 [==============================] - 401s 801ms/step - loss: 0.0131 - accuracy: 0.9890 - mean_iou: 0.5723 - val_loss: 0.0202 - val_accuracy: 0.9863 - val_mean_iou: 0.5552
#
# Epoch 00009: val_loss did not improve from 0.00970
# Epoch 10/15
# 500/500 [==============================] - 401s 802ms/step - loss: 0.0121 - accuracy: 0.9898 - mean_iou: 0.5976 - val_loss: 0.0487 - val_accuracy: 0.9741 - val_mean_iou: 0.2000
#
# Epoch 00010: val_loss did not improve from 0.00970
# Epoch 11/15
# 500/500 [==============================] - 399s 799ms/step - loss: 0.0130 - accuracy: 0.9891 - mean_iou: 0.5786 - val_loss: 0.0213 - val_accuracy: 0.9888 - val_mean_iou: 0.6132
#
# Epoch 00011: val_loss did not improve from 0.00970
# Epoch 00011: early stopping

# %% [markdown]
# ### Imágenes 5D

# %%
from meduy.unet.train import TrainConfig, train
from meduy.unet.evaluate import plot_data_generator
import os

# %%
config_5D_S2 = TrainConfig(width=160,  #  tamaño de la imagen procesada por la UNet (debe ser multiplos de 16 , por ej 160, 320,etc)
                     height=160,
                     n_channels=5, ### #  número de canales de la imagen, rgb -> 3
                     n_classes=1, # número de clases a clasificar
                     apply_image_augmentation=True, #  si es True , amplia el dataset generando imagenes nuevas a partir de pequeñas variaciones de las ya existentes 
                     seed=42,
                     epochs=15, # Cantidad de veces que el dataset entero puede pasar por el proceso de entrenamiento
                     batch_size=32, #cantidad de datos que se procesan por vez, puede ser limitado por la memoria de gpu disponible (debe ser multiplo de 16)
                     steps_per_epoch=500, #  típicamente debe ser igual al numero de imágenes / el batch_size, si es mayor incrementara el número de imágenes generadas con image augmentation
                     early_stopping_patience=3, # a medida que entrena se guarda los resultados del entrenamiento despues de cada epoch, si el error no varió luego de 3 iteraciones , se corta el proceso porque se entiende que el error ya disminuyó significativamente 
                     validation_split=0.2, # se divide la muestra en training y validation para calcular el error durante el proceso de entrenamiento
                     images_path=os.path.join('./data/data_train','S2','5D', '160_60'),### #ruta a las imágenes
                     model_path=os.path.join('./weights/', 'UNet_asentamientos_S2_5D_160_60_spe500.h5')) #  ruta al archivo de entrenamiento

# %%
res_config_5D_S2 = train(config_5D_S2)
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 160, 160, 5)  0
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 160, 160, 32) 1472        input_7[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 160, 160, 32) 9248        conv2d_139[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_31 (MaxPooling2D) (None, 80, 80, 32)   0           conv2d_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 80, 80, 32)   128         max_pooling2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 80, 80, 64)   18496       batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 80, 80, 64)   36928       conv2d_141[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D) (None, 40, 40, 64)   0           conv2d_142[0][0]
# __________________________________________________________________________________________________
# dropout_49 (Dropout)            (None, 40, 40, 64)   0           max_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 40, 40, 64)   256         dropout_49[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 40, 40, 128)  73856       batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 40, 40, 128)  147584      conv2d_143[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_33 (MaxPooling2D) (None, 20, 20, 128)  0           conv2d_144[0][0]
# __________________________________________________________________________________________________
# dropout_50 (Dropout)            (None, 20, 20, 128)  0           max_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 20, 20, 128)  512         dropout_50[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 20, 20, 256)  295168      batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 20, 20, 256)  590080      conv2d_145[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_34 (MaxPooling2D) (None, 10, 10, 256)  0           conv2d_146[0][0]
# __________________________________________________________________________________________________
# dropout_51 (Dropout)            (None, 10, 10, 256)  0           max_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 10, 10, 256)  1024        dropout_51[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 10, 10, 512)  1180160     batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 10, 10, 512)  2359808     conv2d_147[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_35 (MaxPooling2D) (None, 5, 5, 512)    0           conv2d_148[0][0]
# __________________________________________________________________________________________________
# dropout_52 (Dropout)            (None, 5, 5, 512)    0           max_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 5, 5, 1024)   4719616     dropout_52[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 5, 5, 1024)   9438208     conv2d_149[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_31 (Conv2DTran (None, 10, 10, 512)  2097664     conv2d_150[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 10, 10, 1024) 0           conv2d_transpose_31[0][0]
#                                                                  conv2d_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 10, 10, 1024) 4096        concatenate_31[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 10, 10, 512)  4719104     batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 10, 10, 512)  2359808     conv2d_151[0][0]
# __________________________________________________________________________________________________
# dropout_53 (Dropout)            (None, 10, 10, 512)  0           conv2d_152[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_32 (Conv2DTran (None, 20, 20, 256)  524544      dropout_53[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 20, 20, 512)  0           conv2d_transpose_32[0][0]
#                                                                  conv2d_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 20, 20, 512)  2048        concatenate_32[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 20, 20, 256)  1179904     batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 20, 20, 256)  590080      conv2d_153[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 20, 20, 256)  0           conv2d_154[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_33 (Conv2DTran (None, 40, 40, 128)  131200      dropout_54[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 40, 40, 256)  0           conv2d_transpose_33[0][0]
#                                                                  conv2d_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 40, 40, 256)  1024        concatenate_33[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 40, 40, 128)  295040      batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 40, 40, 128)  147584      conv2d_155[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 40, 40, 128)  0           conv2d_156[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_34 (Conv2DTran (None, 80, 80, 64)   32832       dropout_55[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 80, 80, 128)  0           conv2d_transpose_34[0][0]
#                                                                  conv2d_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 80, 80, 128)  512         concatenate_34[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 80, 80, 64)   73792       batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 80, 80, 64)   36928       conv2d_157[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 80, 80, 64)   0           conv2d_158[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_35 (Conv2DTran (None, 160, 160, 32) 8224        dropout_56[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 160, 160, 64) 0           conv2d_transpose_35[0][0]
#                                                                  conv2d_140[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 160, 160, 32) 18464       concatenate_35[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 160, 160, 32) 9248        conv2d_159[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 160, 160, 1)  33          conv2d_160[0][0]
# ==================================================================================================
# Total params: 31,104,673
# Trainable params: 31,099,873
# Non-trainable params: 4,800
# __________________________________________________________________________________________________
# None
# All images: 847
# Num. training images: 678
# Num. validation images: 169
# Compile and fit the UNet model
# Epoch 1/15
# 500/500 [==============================] - 444s 889ms/step - loss: 0.0485 - accuracy: 0.9696 - mean_iou: 0.1118 - val_loss: 0.0369 - val_accuracy: 0.9766 - val_mean_iou: 0.1007
#
# Epoch 00001: val_loss improved from inf to 0.03691, saving model to ./weights/UNet_asentamientos_S2_5D_160_60_spe500.h5
# Epoch 2/15
# 500/500 [==============================] - 429s 858ms/step - loss: 0.0306 - accuracy: 0.9772 - mean_iou: 0.2214 - val_loss: 0.0276 - val_accuracy: 0.9771 - val_mean_iou: 0.2340
#
# Epoch 00002: val_loss improved from 0.03691 to 0.02759, saving model to ./weights/UNet_asentamientos_S2_5D_160_60_spe500.h5
# Epoch 3/15
# 500/500 [==============================] - 440s 880ms/step - loss: 0.0251 - accuracy: 0.9807 - mean_iou: 0.3133 - val_loss: 0.0193 - val_accuracy: 0.9788 - val_mean_iou: 0.3441
#
# Epoch 00003: val_loss improved from 0.02759 to 0.01927, saving model to ./weights/UNet_asentamientos_S2_5D_160_60_spe500.h5
# Epoch 4/15
# 500/500 [==============================] - 445s 891ms/step - loss: 0.0216 - accuracy: 0.9829 - mean_iou: 0.3806 - val_loss: 0.0257 - val_accuracy: 0.9832 - val_mean_iou: 0.3582
#
# Epoch 00004: val_loss did not improve from 0.01927
# Epoch 5/15
# 500/500 [==============================] - 445s 891ms/step - loss: 0.0193 - accuracy: 0.9844 - mean_iou: 0.4353 - val_loss: 0.0201 - val_accuracy: 0.9854 - val_mean_iou: 0.4257
#
# Epoch 00005: val_loss did not improve from 0.01927
# Epoch 6/15
# 500/500 [==============================] - 446s 891ms/step - loss: 0.0175 - accuracy: 0.9857 - mean_iou: 0.4700 - val_loss: 0.0218 - val_accuracy: 0.9864 - val_mean_iou: 0.4448
#
# Epoch 00006: val_loss did not improve from 0.01927
# Epoch 00006: early stopping
